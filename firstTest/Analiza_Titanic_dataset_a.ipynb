# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data['PassengerId'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: PassengerId, dtype: int64

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot('Survived', data=data)
#ax[1].set_title('Survived')

# %%
data['Survived'].value_counts().plot.pie()

# %%
data['Sex'].value_counts().plot.pie()

# %%
sns.countplot('Sex', data=data)

# %%
data.groupby( ['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()

# %%
pd.crosstab(data.Pclass, data.Survived, margins = True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
pd.crosstab(data.Pclass, data.Survived)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(data.Pclass, data.Survived, margins= True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_f607772c_2c41_11e8_9f18_b083fe9a199brow0_col0 {
#             background-color:  #ffff66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow0_col1 {
#             background-color:  #cee666;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow0_col2 {
#             background-color:  #f4fa66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow1_col0 {
#             background-color:  #f6fa66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow1_col1 {
#             background-color:  #ffff66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow1_col2 {
#             background-color:  #ffff66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow2_col0 {
#             background-color:  #60b066;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow2_col1 {
#             background-color:  #dfef66;
#         }    #T_f607772c_2c41_11e8_9f18_b083fe9a199brow2_col2 {
#             background-color:  #90c866;
# ...

# %%
data['Pclass'].value_counts().plot.bar()

# %%
data['Pclass'].value_counts().plot.pie()

# %%
pd.crosstab([data.Sex, data.Survived ], data.Pclass, margins = True)
# Out:
# Pclass             1    2    3  All
# Sex    Survived
# female 0           3    6   72   81
#        1          91   70   72  233
# male   0          77   91  300  468
#        1          45   17   47  109
# All              216  184  491  891

# %%
pd.crosstab([data.Sex, data.Survived ], data.Pclass, margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow0_col0 {
#             background-color:  #ffff66;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow0_col1 {
#             background-color:  #ffff66;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow0_col2 {
#             background-color:  #f1f866;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow0_col3 {
#             background-color:  #ffff66;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow1_col0 {
#             background-color:  #96cb66;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow1_col1 {
#             background-color:  #a3d166;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow1_col2 {
#             background-color:  #f1f866;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow1_col3 {
#             background-color:  #cfe766;
#         }    #T_4a6680e6_2c42_11e8_a1ec_b083fe9a199brow2_col0 {
#             background-color:  #a7d366;
# ...

# %%
pd.crosstab([data.Survived ], data.Pclass, margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_60b26850_2c42_11e8_aa00_b083fe9a199brow0_col0 {
#             background-color:  #ffff66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow0_col1 {
#             background-color:  #e5f266;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow0_col2 {
#             background-color:  #51a866;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow0_col3 {
#             background-color:  #9fcf66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow1_col0 {
#             background-color:  #96cb66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow1_col1 {
#             background-color:  #ffff66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow1_col2 {
#             background-color:  #ffff66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow1_col3 {
#             background-color:  #ffff66;
#         }    #T_60b26850_2c42_11e8_aa00_b083fe9a199brow2_col0 {
#             background-color:  #008066;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)

# %%
# deskriptivna statistika
data['Age'].max()
# Out:
# 80.0

# %%
data['Age'].min()
# Out:
# 0.42

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True)

# %%
# Odabir putnika koji su preziveli
data[data['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
data[data['Survived']==1].Age
# Out:
# 1      38.00
# 2      26.00
# 3      35.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 15     55.00
# 17       NaN
# 19       NaN
# 21     34.00
# 22     15.00
# 23     28.00
# 25     38.00
# 28       NaN
# 31       NaN
# 32       NaN
# 36       NaN
# 39     14.00
# 43      3.00
# 44     19.00
# 47       NaN
# 52     49.00
# 53     29.00
# 55       NaN
# 56     21.00
# 58      5.00
# 61     38.00
# 65       NaN
# 66     29.00
#        ...
# 809    33.00
# 820    52.00
# 821    27.00
# 823    27.00
# 827     1.00
# 828      NaN
# 829    62.00
# 830    15.00
# 831     0.83
# 835    39.00
# 838    32.00
# 839      NaN
# 842    30.00
# 849      NaN
# 853    16.00
# 855    18.00
# 856    45.00
# 857    51.00
# 858    24.00
# 862    48.00
# 865    42.00
# 866    27.00
# 869     4.00
# 871    47.00
# 874    28.00
# 875    15.00
# 879    56.00
# 880    25.00
# 887    19.00
# 889    26.00
# Name: Age, Length: 342, dtype: float64

# %%
data[data['Survived']==1].Age.plot.hist(bins = 20)

# %%
data[data['Survived']==0].Age.plot.hist(bins = 20)

# %%
data [data['Age']> 60].shape
# Out:
# (22, 12)

# %%
# Proveriti koliko je osoba starijih od 60 godina bilo na Titaniku

len (data [data['Age']> 50])
# Out:
# 64

# %%
len ( data [ (data['Age'> 30] ) and (data['Age'] < 50 ])  )
# Out:
#   File "<ipython-input-63-367c4e74351f>", line 1
#     len ( data [ (data['Age']> 30) and (data['Age'] < 50 ])  )
#                                                          ^
# SyntaxError: invalid syntax

# %%
# Na ovaj nacin omozemo da proverimo koliko se osoba 
# nalazilo u odgovarajucem starosnom intervalu

len (data [ (data ['Age'] > 30 )  &   (data ['Age'] < 50) ]   )
# Out:
# 231

# %%
# dodatan nacin za pristupanju 
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
