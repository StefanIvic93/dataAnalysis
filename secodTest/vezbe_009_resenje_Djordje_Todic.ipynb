# %%
import pandas as pd

# %%
from pandas import Series

# %%
data=pd.read_csv('bitcoin_cash_price.csv',header=0) #Učitavanje data-seta

# %%
data.head(10)
# Out:
#            Date     Open     High      Low    Close       Volume  \
# 0  Feb 20, 2018  1543.27  1569.03  1414.35  1418.73  820,947,000
# 1  Feb 19, 2018  1483.34  1553.81  1483.34  1534.77  578,906,000
# 2  Feb 18, 2018  1552.10  1641.40  1428.49  1487.46  907,873,000
# 3  Feb 17, 2018  1548.48  1568.64  1517.14  1551.39  641,719,000
# 4  Feb 16, 2018  1373.16  1558.66  1369.68  1552.20  961,010,000
# 5  Feb 15, 2018  1358.65  1400.71  1330.18  1375.81  502,454,000
# 6  Feb 14, 2018  1229.18  1384.06  1229.18  1362.27  629,852,000
# 7  Feb 13, 2018  1285.23  1289.42  1205.73  1231.98  442,663,000
# 8  Feb 12, 2018  1222.43  1302.66  1222.43  1283.91  466,213,000
# 9  Feb 11, 2018  1255.59  1306.20  1197.87  1217.64  651,555,000
#
#        Market Cap
# 0  26,199,800,000
# 1  25,179,700,000
# 2  26,344,200,000
# 3  26,280,100,000
# 4  23,302,000,000
# 5  23,053,300,000
# 6  20,854,300,000
# 7  21,803,000,000
# 8  20,735,400,000
# 9  21,295,600,000

# %%
data['Date'] = pd.to_datetime(data['Date'])  #Promena tipa datuma.

# %%
type(data.Date[1])
# Out:
# pandas._libs.tslib.Timestamp

# %%
data.Close.values
# Out:
# array([1418.73, 1534.77, 1487.46, 1551.39, 1552.2 , 1375.81, 1362.27,
#        1231.98, 1283.91, 1217.64, 1257.31, 1312.11, 1284.56,  957.96,
#         974.52,  887.41, 1165.38, 1272.5 , 1191.14, 1274.35, 1486.89,
#        1470.55, 1657.14, 1746.25, 1628.63, 1603.9 , 1642.12, 1639.13,
#        1621.46, 1621.92, 1776.64, 2032.12, 1769.62, 1756.75, 1748.05,
#        1772.07, 2401.54, 2553.32, 2685.29, 2620.99, 2462.61, 2895.38,
#        2391.56, 2421.47, 2786.88, 2786.65, 2584.48, 2430.18, 2608.69,
#        2711.  , 2432.54, 2533.01, 2392.41, 2779.95, 2566.64, 2889.52,
#        3108.89, 2954.69, 2903.12, 3257.08, 2696.69, 3267.17, 3923.07,
#        2805.89, 2196.64, 1862.88, 1801.88, 1815.43, 1966.14, 1607.65,
#        1615.03, 1423.38, 1323.07, 1410.06, 1464.13, 1330.93, 1430.1 ,
#        1501.85, 1576.92, 1559.93, 1434.98, 1462.68, 1389.78, 1359.71,
#        1546.18, 1622.57, 1735.66, 1571.27, 1648.51, 1683.81, 1303.31,
# ...

# %%
close=Series(data=data['Close'].values,index=data.Date)  #Kreiranje serije sa vrednostima iz kolone "Close"

# %%
close.head(10)
# Out:
# Date
# 2018-02-20    1418.73
# 2018-02-19    1534.77
# 2018-02-18    1487.46
# 2018-02-17    1551.39
# 2018-02-16    1552.20
# 2018-02-15    1375.81
# 2018-02-14    1362.27
# 2018-02-13    1231.98
# 2018-02-12    1283.91
# 2018-02-11    1217.64
# dtype: float64

# %%
from matplotlib import pyplot
# %matplotlib inline

# %%
pyplot.plot(close,c='r')         #Crtanje grafika kretanja vrednosti bitcoin-a

# %%
close_2017=Series(close['2017'])  #Izdvajanje serije iz godine 2017.

# %%
close_2017.head(10)
# Out:
# Date
# 2017-12-31    2533.01
# 2017-12-30    2392.41
# 2017-12-29    2779.95
# 2017-12-28    2566.64
# 2017-12-27    2889.52
# 2017-12-26    3108.89
# 2017-12-25    2954.69
# 2017-12-24    2903.12
# 2017-12-23    3257.08
# 2017-12-22    2696.69
# dtype: float64

# %%
close_2017_max=close_2017.max()

# %%
close_2017_max #maksimalna vrednost u 2017.
# Out:
# 3923.07

# %%
close_2017.argmax()  #datum kada je postignut maksimum 2017.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# Timestamp('2017-12-20 00:00:00')

# %%
close_2017['2017-12-20']
# Out:
# Date
# 2017-12-20    3923.07
# dtype: float64

# %%
close_2018=Series(close['2018'])  #Izdvajanje serije iz godine 2018.

# %%
close_2018_max=close_2018.max()

# %%
close_2018_max  #maksimum u 2018.
# Out:
# 2895.38

# %%
close_2018.argmax() #datum kada je postignut maksimum u 2018.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# Timestamp('2018-01-10 00:00:00')

# %%
close_2018['2018-01-10']
# Out:
# Date
# 2018-01-10    2895.38
# dtype: float64

# %%
from pandas.tools.plotting import autocorrelation_plot
autocorrelation_plot(close)
pyplot.show()

#Mozemo reći da se velika zavisnost javlja pošto vrednosti autokorelacije teže vrednosti 1.
#Grafik autokorelacije.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
from pandas import DataFrame
from pandas import concat
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
values=DataFrame(close_2018.values)
dataframe=concat([values.shift(1),values],axis=1)
dataframe.columns=['t','t+1']
print(dataframe.head(5))
X=dataframe.values
train,test = X[1:len(X)-7],X[len(X)-7:]
train_X,train_y=train[:,0],train[:,1]
test_X,test_y=test[:,0],test[:,1]
def model_persistence(x):                            #Primer persistance modela,train i test seta.
    return x
predictions= list()
for x in train_X:
    yhat=model_persistence(x)
    predictions.append(yhat)
rmse=np.sqrt(mean_squared_error(train_y,predictions))
print('Test RMSE: %.3f '%rmse)
pyplot.plot(train_y)
pyplot.plot(predictions,color='red')
pyplot.show()
#Ovim smo pokazali da kretanje bitcoin-a možemo pretpostaviti jedan dan unapred.
# Out:
#          t      t+1
# 0      NaN  1418.73
# 1  1418.73  1534.77
# 2  1534.77  1487.46
# 3  1487.46  1551.39
# 4  1551.39  1552.20
# Test RMSE: 184.806

# %%
vektor_greske= train_y - predictions           #Vrednosti greške predikcije

# %%
pyplot.hist(vektor_greske)
# Out:
# (array([ 1.,  1.,  2.,  7., 18.,  8.,  4.,  0.,  1.,  1.]),
#  array([-503.82 , -390.491, -277.162, -163.833,  -50.504,   62.825,
#          176.154,  289.483,  402.812,  516.141,  629.47 ]),
#  <a list of 10 Patch objects>)

# %%
autocorrelation_plot(vektor_greske)        #Autokorelacioni grafik za vrednost greške.
pyplot.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange
close_2017=[i+randrange(10)for i in range(1,100)]
result=seasonal_decompose(close_2017,model='additive',freq=int(len(close_2017)/7))
result.plot()
pyplot.show()
#Aditivna dekompozicija na nedeljnom nivou.

# %%
result=seasonal_decompose(close_2017,model='multiplicative',freq=int(len(close_2017)/7))
result.plot()
pyplot.show()
#Multiplikativna dekompozicija na nedeljnom nivou.
